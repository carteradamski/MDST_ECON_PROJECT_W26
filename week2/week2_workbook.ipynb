# %% [markdown]
# # Here is the week 2 Workbook
#
# Try to do this on your own, I will release solutions after today
#
# Download the 3 csv files that came along with this presentation (though you will come back to use this with any files.)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Set style for better-looking plots
plt.style.use('seaborn-v0_8-darkgrid')
# %matplotlib inline

# %%
# Load Data
CPI = pd.read_csv('CPI.csv')
INFLATION = pd.read_csv('T5YIE.csv')
UNRATE = pd.read_csv('UNRATE.csv')
FEDFUNDS = pd.read_csv('FEDFUNDS.csv')
CUNRATE = pd.read_csv('CUNRATE.csv')

# %%
#TODO Generate a bar graph of the average unenployment every month;

# %%
#TODO: generate a plot with the fed funds rate over time

# %%
# Merge the dataframes on the date column
merged_data = pd.merge(UNRATE, FEDFUNDS, on='observation_date')

#Todo Generte a scatter plot showing the relationship between unemployment rate and federal funds rate (use the merged data with UNRATE and FEDFUNDS)

# %%
merged = pd.merge(UNRATE, CUNRATE, on='observation_date')

# Remove any rows with NaN values
merged_clean = merged.dropna()
#TODO: Create a scatter plot showing the relationship between unemployment rate and college unemployment rate (CGBD2534)
# Out:
# Linear regression equation: Inflation Rate = 0.58 * Unemployment Rate + 0.03
# Correlation coefficient between Unemployment Rate and Inflation Rate: 0.86

# %% [markdown]
# # Feel Free to Make anythig else or experiment correlation between any other variables
